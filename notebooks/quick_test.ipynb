# %% [markdown]
# # tdf_qutip — quick test
#
# Smoke-import project modules. Implement stubs before expecting numerical output.

# %%
import sys
from pathlib import Path

# Allow imports from repo root when cwd is notebooks/
ROOT = Path.cwd().resolve().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from config.params import default_params
import qutip as qt

default_params()
